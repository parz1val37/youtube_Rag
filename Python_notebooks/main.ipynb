# %% [markdown]
# # Testing the RAG Model
# - import all functions and run

# %%
import pandas as pd
import json
from all_functions import fetch_transcript, create_embeddings, fetch_relevant_chunk, LLM_response, merge_chunks

# %%
yt = 'https://youtu.be/DFwppvrL_pE?si=wO5NE7e5jajBvXsX'

# %%
transcript = fetch_transcript.fetch_transcript(yt)

# %%
new_transcript, summary = merge_chunks(transcript) #type: ignore

# %%
transcript = create_embeddings.create_embeddings(new_transcript)

# %%
dataframe = pd.DataFrame(transcript)

# %%
query = input("Ask about this video: ")

# %%
rlvnt_chnk = fetch_relevant_chunk.fetch_relevant_chunk(query, dataframe)

# %%
LLM_response.LLM_response(query, rlvnt_chnk, summary)
